# %% [markdown]
# # https://tncentral.ncc.unesp.br/data_download

# %%
# Nucleotide Databases
## TnCentral + ISFinder
# Baixar no pc depois enviar para o servidor
scp "C:\Users\vitor\Downloads\nc_tncentral_isfinder.fa.zip" victorbaca@10.20.34.31:/mnt/dados/victor_baca/
cd /mnt/dados/victor_baca
mkdir nc_tncentral_isfinder
mv nc_tncentral_isfinder* nc_tncentral_isfinder
cd nc_tncentral_isfinder
unzip nc_tncentral_isfinder.fa.zip
